# %%
# %pip install glob
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import glob
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cnt = len(glob.glob(r'E:\project\New_Data\Image\annotations\*'))
cnt
# Out:
# 90640

# %%
a = [1,2,3]

b = [[4,5,6], [7,8,9], [10, 11, 12]]
a = a[-2:-1]
print(a)
a.extend(b)
print(a)
# Out:
# [2]
# [2, [4, 5, 6], [7, 8, 9], [10, 11, 12]]

# %%
a = False
if a != False:
    print(123)

# %%
b = 'a'*0
print(b == '')
# Out:
# True

# %%
a = [1,2,3,4,5]
print(a.index(1))
# Out:
# 0

# %%
a = glob.glob('E:\\project\\Data\\Data\\Data\\Training\\SourceData\\TS\\Image\\*\\*\\*\\*.jpg')
b = glob.glob('E:\\project\\Data\\Data\\Data\\Training\\SourceData\\TS\\Image\\*\\*\\*\\*.JPG')
print(len(a), len(b))
# Out:
# 181280 181280

# %%
data_root = r'E:\project\New_Data'
file_root = rf'{data_root}\Image'
project_name = 'fall_detection'
print(file_root)
train_root = rf'{data_root}\train'
valid_root = rf'{data_root}\valid'
test_root = rf'{data_root}\test'
cls_list = ['Normal', 'Fall']
cls_filename_list = ['N', 'BY', 'FY', 'SY']

image_root = f'{train_root}\\images'
label_root = f'{train_root}\\labels'

image_list = sorted(glob.glob(f'{image_root}\\*.jpg'))
label_list = sorted(glob.glob(f'{label_root}\\*'))
print(len(image_list), len(label_list))
# Out:
# E:\project\New_Data\Image
# 67840 67840

# %%
print(cv2.COLOR_RGB2BGR)
# Out:
# 4

# %%
plt.figure(figsize=(10, 50))
for i, (img_src, lbl) in enumerate(zip(image_list, label_list)): 
    print(lbl)
    with open(lbl, 'r', encoding='utf-8') as f:
        label_str = f.read()
        bbox = list(map(float, label_str.split(' ')[1:]))
        print(bbox)
    bbox = [int(x * 640) for x in bbox]
    print(bbox)
    bbox = [
        int(bbox[0] - bbox[2] / 2),
        int(bbox[1] - bbox[3] / 2),
        int(bbox[0] + bbox[2] / 2),
        int(bbox[1] + bbox[3] / 2),
    ]
    print(img_src)
    img = cv2.imread(img_src)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    bbox_img = cv2.rectangle(img, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 0, 0), 2)
    plt.subplot(1, 5, (i+1))
    plt.imshow(bbox_img)

    if i == 4:
        break
plt.show()
# Out:
# E:\project\New_Data\train\labels\00004_H_A_SY_C1_I001.txt
# [0.4946467717488606, 0.605328623453776, 0.20393384297688805, 0.34136034647623703]
# [316, 387, 130, 218]
# E:\project\New_Data\train\images\00004_H_A_SY_C1_I001.jpg
# E:\project\New_Data\train\labels\00004_H_A_SY_C1_I002.txt
# [0.46136215527852376, 0.61636270682017, 0.270290470123291, 0.32336106300354006]
# [295, 394, 172, 206]
# E:\project\New_Data\train\images\00004_H_A_SY_C1_I002.jpg
# E:\project\New_Data\train\labels\00004_H_A_SY_C1_I003.txt
# [0.5132503509521484, 0.6132283449172974, 0.23896586100260414, 0.31591099103291825]
# [328, 392, 152, 202]
# E:\project\New_Data\train\images\00004_H_A_SY_C1_I003.jpg
# E:\project\New_Data\train\labels\00004_H_A_SY_C1_I004.txt
# [0.5573563257853189, 0.5661397218704224, 0.23737322489420576, 0.3979333400726318]
# [356, 362, 151, 254]
# E:\project\New_Data\train\images\00004_H_A_SY_C1_I004.jpg
# E:\project\New_Data\train\labels\00004_H_A_SY_C1_I005.txt
# [0.6732475280761718, 0.5913238525390625, 0.2818258921305338, 0.24150962829589845]
# [430, 378, 180, 154]
# E:\project\New_Data\train\images\00004_H_A_SY_C1_I005.jpg

# %%
del a
del b
a = 1
if a == 1:
    b = 1
print(b)
# Out:
# 1

# %%
a = [1,2,3,4,5]
for i in range(len(a)):
    print(a[i-1])
# Out:
# 5
# 1
# 2
# 3
# 4

# %%
a = [1,2,3,4,5]
b = len(a) - 1
if a.index(5) == b:
    print(1234)
# Out:
# 1234

# %%
print(list(map(lambda x, y: x + y, [1,2,3,4,5], [11, 12, 13, 14, 15])))
# Out:
# [12, 14, 16, 18, 20]

# %%
[n for n in range(0, 50, 5)]
# Out:
# [0, 5, 10, 15, 20, 25, 30, 35, 40, 45]
